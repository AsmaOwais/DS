# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt 
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Asma Owais - content_based_recommendation_dataset (1).csv')

# %%
df
# Out:
#       Number of clicks on similar products  \
# 0                                       12
# 1                                        8
# 2                                       25
# 3                                        6
# 4                                       18
# ...                                    ...
# 1469                                     5
# 1470                                    37
# 1471                                    22
# 1472                                    40
# 1473                                    12
#
#       Number of similar products purchased so far  \
# 0                                               4
# 1                                               2
# 2                                              10
# 3                                               1
# 4                                               5
# ...                                           ...
# 1469                                            1
# ...

# %% [markdown]
# **1. Load the dataset and Diaplay first 5 rows?**

# %%
df.head()
# Out:
#    Number of clicks on similar products  \
# 0                                    12
# 1                                     8
# 2                                    25
# 3                                     6
# 4                                    18
#
#    Number of similar products purchased so far  \
# 0                                            4
# 1                                            2
# 2                                           10
# 3                                            1
# 4                                            5
#
#    Average rating given to similar products  Gender  \
# 0                                       4.2    male
# 1                                       3.8  female
# 2                                       4.5  female
# 3                                       2.1  female
# 4                                       4.7    male
#
#    Median purchasing price (in rupees)  Rating of the product  \
# ...

# %% [markdown]
# **2. Display dataset shape and columns names?**

# %%
df.shape
# Out:
# (1474, 13)

# %%
df.columns
# Out:
# Index(['Number of clicks on similar products',
#        'Number of similar products purchased so far',
#        'Average rating given to similar products', 'Gender',
#        'Median purchasing price (in rupees)', 'Rating of the product',
#        'Brand of the product', 'Customer review sentiment score (overall)',
#        'Price of the product', 'Holiday', 'Season', 'Geographical locations',
#        'Probability for the product to be recommended to the person'],
#       dtype='object')

# %% [markdown]
# **3. Check datatypes of all column?**

# %%
df.dtypes
# Out:
# Number of clicks on similar products                             int64
# Number of similar products purchased so far                      int64
# Average rating given to similar products                       float64
# Gender                                                          object
# Median purchasing price (in rupees)                              int64
# Rating of the product                                          float64
# Brand of the product                                            object
# Customer review sentiment score (overall)                      float64
# Price of the product                                             int64
# Holiday                                                         object
# Season                                                          object
# Geographical locations                                          object
# Probability for the product to be recommended to the person    float64
# dtype: object

# %% [markdown]
# **4. Identify missing values in each column?**

# %%
df.isnull().sum()
# Out:
# Number of clicks on similar products                           0
# Number of similar products purchased so far                    0
# Average rating given to similar products                       0
# Gender                                                         0
# Median purchasing price (in rupees)                            0
# Rating of the product                                          0
# Brand of the product                                           0
# Customer review sentiment score (overall)                      0
# Price of the product                                           0
# Holiday                                                        0
# Season                                                         0
# Geographical locations                                         0
# Probability for the product to be recommended to the person    0
# dtype: int64

# %% [markdown]
# **5. Handle missing values?**

# %%
df = df.fillna(method='ffill')

# %%
df
# Out:
#       Number of clicks on similar products  \
# 0                                       12
# 1                                        8
# 2                                       25
# 3                                        6
# 4                                       18
# ...                                    ...
# 1469                                     5
# 1470                                    37
# 1471                                    22
# 1472                                    40
# 1473                                    12
#
#       Number of similar products purchased so far  \
# 0                                               4
# 1                                               2
# 2                                              10
# 3                                               1
# 4                                               5
# ...                                           ...
# 1469                                            1
# ...

# %% [markdown]
# **6.Check and remove duplicate rows?**

# %%
 df.drop_duplicates()
# Out:
#       Number of clicks on similar products  \
# 0                                       12
# 1                                        8
# 2                                       25
# 3                                        6
# 4                                       18
# ...                                    ...
# 1469                                     5
# 1470                                    37
# 1471                                    22
# 1472                                    40
# 1473                                    12
#
#       Number of similar products purchased so far  \
# 0                                               4
# 1                                               2
# 2                                              10
# 3                                               1
# 4                                               5
# ...                                           ...
# 1469                                            1
# ...

# %%
df=df.drop_duplicates()

# %%
df
# Out:
#       Number of clicks on similar products  \
# 0                                       12
# 1                                        8
# 2                                       25
# 3                                        6
# 4                                       18
# ...                                    ...
# 1469                                     5
# 1470                                    37
# 1471                                    22
# 1472                                    40
# 1473                                    12
#
#       Number of similar products purchased so far  \
# 0                                               4
# 1                                               2
# 2                                              10
# 3                                               1
# 4                                               5
# ...                                           ...
# 1469                                            1
# ...

# %% [markdown]
# **7.Generate summary statistics?**

# %%
df.describe()
# Out:
#        Number of clicks on similar products  \
# count                           1018.000000
# mean                              21.397839
# std                               12.103449
# min                                0.000000
# 25%                               11.000000
# 50%                               20.000000
# 75%                               31.000000
# max                               55.000000
#
#        Number of similar products purchased so far  \
# count                                  1018.000000
# mean                                      9.017682
# std                                       5.740169
# min                                       0.000000
# 25%                                       4.000000
# 50%                                       8.000000
# 75%                                      14.000000
# max                                      24.000000
#
#        Average rating given to similar products  \
# ...

# %% [markdown]
# **8. Calculate the average of 'Price of the product'?**

# %%
df['Price of the product'].mean()
# Out:
# np.float64(1334.9214145383105)

# %% [markdown]
# **9.Find max and min of 'median purchasing price(in rupees)'?**

# %%
df['Median purchasing price (in rupees)'].max()
# Out:
# 19000

# %%
df['Median purchasing price (in rupees)'].min()
# Out:
# 100

# %% [markdown]
# **10. Value count of 'Brand of the product'?**

# %%
df['Brand of the product'].value_counts()
# Out:
# Brand of the product
# Wildcraft                          74
# Manyavar Mohey                     58
# Pepperfry                          55
# Flying Machine                     52
# Patanjali Ayurved (Health Care)    50
# Lee                                46
# Lakme Ayurveda                     45
# Wakefit                            41
# Johnson & Johnson                  40
# Khadi Essentials                   34
# Pepe Jeans London                  33
# Kama Ayurveda                      32
# Max                                29
# PUMA                               25
# Head Hunters                       24
# Himalaya Liv.52                    24
# Sugar Cosmetics                    24
# Fastrack                           22
# The Moms Co.                       22
# Dettol                             21
# Urban Ladder                       20
# SleepyCat                          20
# AmazonBasics                       17
# Allen Solly Woman                  16
# ...

# %% [markdown]
# **11.sort data by 'Price of the product'?**

# %%
df.sort_values(by='Price of the product')
# Out:
#       Number of clicks on similar products  \
# 752                                     40
# 764                                     39
# 788                                     34
# 1282                                    10
# 1303                                     7
# ...                                    ...
# 863                                     35
# 1444                                    14
# 20                                      28
# 855                                     50
# 958                                     35
#
#       Number of similar products purchased so far  \
# 752                                            16
# 764                                            15
# 788                                            13
# 1282                                            0
# 1303                                            1
# ...                                           ...
# 863                                            14
# ...

# %% [markdown]
# **12. Filter data where rating>4?**

# %%
df[df['Rating of the product'] > 4]
# Out:
#       Number of clicks on similar products  \
# 0                                       12
# 2                                       25
# 4                                       18
# 6                                       38
# 9                                       10
# ...                                    ...
# 1467                                    43
# 1468                                    21
# 1470                                    37
# 1471                                    22
# 1472                                    40
#
#       Number of similar products purchased so far  \
# 0                                               4
# 2                                              10
# 4                                               5
# 6                                              15
# 9                                               4
# ...                                           ...
# 1467                                           14
# ...

# %% [markdown]
# **13.Create new column 'Price Differece'?**

# %%
df['Price Difference'] = df['Price of the product'] - df['Median purchasing price (in rupees)']

# %%
df
# Out:
#       Number of clicks on similar products  \
# 0                                       12
# 1                                        8
# 2                                       25
# 3                                        6
# 4                                       18
# ...                                    ...
# 1469                                     5
# 1470                                    37
# 1471                                    22
# 1472                                    40
# 1473                                    12
#
#       Number of similar products purchased so far  \
# 0                                               4
# 1                                               2
# 2                                              10
# 3                                               1
# 4                                               5
# ...                                           ...
# 1469                                            1
# ...

# %% [markdown]
# **14. Groupby average price by gender?**

# %%
df.groupby('Gender')['Price of the product'].mean()
# Out:
# Gender
# female     783.638171
# male      1873.359223
# Name: Price of the product, dtype: float64

# %% [markdown]
# **15. create histogram price of the product?**

# %%
plt.hist(df['Price of the product'])
plt.title("Price Distribution")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# **CONCLUSION**

# %% [markdown]
# **Write 4 to 5 lines explaining:
# • Which factor influences recommendations the most?
# • What changes did you observe after cleaning the data?
# • One interesting pattern you found.**

# %% [markdown]
# **Conclusion:
# The analysis shows that product price and user ratings have a strong influence on recommendation probability. After cleaning the data by handling missing values and removing duplicates, the dataset became more reliable and easier to analyze. It was observed that products with higher ratings and moderate prices tend to be recommended more frequently. Additionally, customer behavior factors such as purchase history also play an important role in recommendations. Overall, the cleaned data provided clearer insights and improved the quality of analysis.**

# %%
Islamic_countries=["Saudia arabia","Pakistan","Malaysia","Syria","Palestine","Qatar"]

# %%
print(Islamic_countries)
# Out:
# ['Saudia arabia', 'Pakistan', 'Malaysia', 'Syria', 'Palestine', 'Qatar']

# %%
print(Islamic_countries[0])
print(Islamic_countries[1])
print(Islamic_countries[2])
print(Islamic_countries[3])
print(Islamic_countries[4])
print(Islamic_countries[5])
# Out:
# Saudia arabia
# Pakistan
# Malaysia
# Syria
# Palestine
# Qatar

# %%
for country_to_check in Islamic_countries:
    print(country_to_check)
# Out:
# Saudia arabia
# Pakistan
# Malaysia
# Syria
# Palestine
# Qatar

# %%
Islamic_countries=["Saudia arabia","Pakistan","Malaysia","Syria","Palestine","Qatar"]
country_name=input("Enter country name")
for country_to_check in Islamic_countries:
    if country_name == country_to_check:
        print("It is an islamic country")
# Out:
# Enter country name africa

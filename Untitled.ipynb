# %%
cleancities = [ "karachi", "faislabad", "multan", "sukkur","hyderabad"]
city_name = input(" Enter city name")
for i in cleancities:
    if city_name == i:
        print("it is a clean city")
# Out:
#  Enter city name karachi
# it is a clean city

# %%
firstname = [ "Ali","Asma", "Owais"]
lastname = [ "Rauf","Irfan","Ahmed"]
for first in firstname:
    for last in lastname:
        print(first+" "+last)
# Out:
# Ali Rauf
# Ali Irfan
# Ali Ahmed
# Asma Rauf
# Asma Irfan
# Asma Ahmed
# Owais Rauf
# Owais Irfan
# Owais Ahmed

# %%
my_dict = {
    "name":"Asma Irfan",
    "position":"student",
    "age":"19",
}

# %%
my_dict
# Out:
# {'name': 'Asma Irfan', 'position': 'student', 'age': '19'}

# %%
my_dict=["name"]

# %%
dir({})
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']
